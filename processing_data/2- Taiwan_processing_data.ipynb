# %%
import pandas as pd
import numpy as np
import gzip
import json
import shutil
from pathlib import Path

# %% [markdown]
# The aim is to read the data from a CSV file after wrangling it, and then read it with csv.DictReader and append it to the JSON file we created.

# %% [markdown]
# # processing data in csv file

# %% [markdown]
# The overall purpose of this wrangle() function is to read a CSV file, perform various data cleaning and transformation steps, and return the resulting DataFrame with the modifications applied.

# %%
def wrangle(file_path):
    df = pd.read_csv(file_path,low_memory=False,encoding='latin-1')
    
    start_index = 1  # Starting index for the new column names
    column_range = range(1, 96)  # Range of columns to be renamed

    for i, col_index in enumerate(column_range):
        new_col_name = f"Attr_{start_index + i}"
        df.rename(columns={df.columns[col_index]: new_col_name}, inplace=True)
    
    # insert column 'company_id'
    df.insert(0, 'id', range(1, len(df) + 1))

    # rename 'class' column to 'bankrupt'
    df = df.rename(columns={'Flag':'bankrupt'})
    
    df["bankrupt"]=[True if v==1 else False for v in df["bankrupt"]]
    
    # remove '?' values 
    df = df.replace({'?': 'NaN'})
    
#     df= df.astype({c: "float64" for c in df.columns[1:65]})
#     df['bankrupt'] = df['bankrupt'].astype(bool)
    
    return df

# %%
df = wrangle(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy.csv")
print(df.shape)
df.head()
# Out:
# (6819, 97)
#    id  bankrupt    Attr_1    Attr_2    Attr_3    Attr_4    Attr_5    Attr_6  \
# 0   1      True  0.370594  0.424389  0.405750  0.601457  0.601457  0.998969
# 1   2      True  0.464291  0.538214  0.516730  0.610235  0.610235  0.998946
# 2   3      True  0.426071  0.499019  0.472295  0.601450  0.601364  0.998857
# 3   4      True  0.399844  0.451265  0.457733  0.583541  0.583541  0.998700
# 4   5      True  0.465022  0.538432  0.522298  0.598783  0.598783  0.998973
#
#      Attr_7    Attr_8  ...   Attr_86   Attr_87   Attr_88   Attr_89   Attr_90  \
# 0  0.796887  0.808809  ...  0.716845  0.009219  0.622879  0.601453  0.827890
# 1  0.797380  0.809301  ...  0.795297  0.008323  0.623652  0.610237  0.839969
# 2  0.796403  0.808388  ...  0.774670  0.040003  0.623841  0.601449  0.836774
# 3  0.796967  0.808966  ...  0.739555  0.003252  0.622929  0.583538  0.834697
# 4  0.797366  0.809304  ...  0.795016  0.003878  0.623521  0.598782  0.839973
#
#     Attr_91   Attr_92   Attr_93  Attr_94   Attr_95
# 0  0.290202  0.026601  0.564050        1  0.016469
# 1  0.283846  0.264577  0.570175        1  0.020794
# 2  0.290189  0.026555  0.563706        1  0.016474
# 3  0.281721  0.026697  0.564663        1  0.023982
# 4  0.278514  0.024752  0.575617        1  0.035490
#
# [5 rows x 97 columns]

# %%
df["bankrupt"].value_counts()
# Out:
# False    6599
# True      220
# Name: bankrupt, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 97 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        6819 non-null   int64
#  1   bankrupt  6819 non-null   bool
#  2   Attr_1    6819 non-null   float64
#  3   Attr_2    6819 non-null   float64
#  4   Attr_3    6819 non-null   float64
#  5   Attr_4    6819 non-null   float64
#  6   Attr_5    6819 non-null   float64
#  7   Attr_6    6819 non-null   float64
#  8   Attr_7    6819 non-null   float64
#  9   Attr_8    6819 non-null   float64
#  10  Attr_9    6819 non-null   float64
#  11  Attr_10   6819 non-null   float64
#  12  Attr_11   6819 non-null   float64
#  13  Attr_12   6819 non-null   float64
#  14  Attr_13   6819 non-null   float64
#  15  Attr_14   6819 non-null   float64
#  16  Attr_15   6819 non-null   float64
#  17  Attr_16   6819 non-null   float64
#  18  Attr_17   6819 non-null   float64
#  19  Attr_18   6819 non-null   float64
#  20  Attr_19   6819 non-null   float64
#  21  Attr_20   6819 non-null   float64
#  22  Attr_21   6819 non-null   float64
#  23  Attr_22   6819 non-null   float64
#  24  Attr_23   6819 non-null   float64
#  25  Attr_24   6819 non-null   float64
#  26  Attr_25   6819 non-null   float64
#  27  Attr_26   6819 non-null   float64
#  28  Attr_27   6819 non-null   float64
#  29  Attr_28   6819 non-null   float64
#  30  Attr_29   6819 non-null   float64
#  31  Attr_30   6819 non-null   float64
#  32  Attr_31   6819 non-null   float64
#  33  Attr_32   6819 non-null   float64
#  34  Attr_33   6819 non-null   float64
#  35  Attr_34   6819 non-null   float64
#  36  Attr_35   6819 non-null   float64
#  37  Attr_36   6819 non-null   float64
#  38  Attr_37   6819 non-null   float64
#  39  Attr_38   6819 non-null   float64
#  40  Attr_39   6819 non-null   float64
#  41  Attr_40   6819 non-null   float64
#  42  Attr_41   6819 non-null   float64
#  43  Attr_42   6819 non-null   float64
#  44  Attr_43   6819 non-null   float64
#  45  Attr_44   6819 non-null   float64
#  46  Attr_45   6819 non-null   float64
#  47  Attr_46   6819 non-null   float64
#  48  Attr_47   6819 non-null   float64
#  49  Attr_48   6819 non-null   float64
#  50  Attr_49   6819 non-null   float64
#  51  Attr_50   6819 non-null   float64
#  52  Attr_51   6819 non-null   float64
#  53  Attr_52   6819 non-null   float64
#  54  Attr_53   6819 non-null   float64
#  55  Attr_54   6819 non-null   float64
#  56  Attr_55   6819 non-null   float64
#  57  Attr_56   6819 non-null   float64
#  58  Attr_57   6819 non-null   float64
#  59  Attr_58   6819 non-null   float64
#  60  Attr_59   6819 non-null   float64
#  61  Attr_60   6819 non-null   float64
#  62  Attr_61   6819 non-null   float64
#  63  Attr_62   6819 non-null   float64
#  64  Attr_63   6819 non-null   float64
#  65  Attr_64   6819 non-null   float64
#  66  Attr_65   6819 non-null   float64
#  67  Attr_66   6819 non-null   float64
#  68  Attr_67   6819 non-null   float64
#  69  Attr_68   6819 non-null   float64
#  70  Attr_69   6819 non-null   float64
#  71  Attr_70   6819 non-null   float64
#  72  Attr_71   6819 non-null   float64
#  73  Attr_72   6819 non-null   float64
#  74  Attr_73   6819 non-null   float64
#  75  Attr_74   6819 non-null   float64
#  76  Attr_75   6819 non-null   float64
#  77  Attr_76   6819 non-null   float64
#  78  Attr_77   6819 non-null   float64
#  79  Attr_78   6819 non-null   float64
#  80  Attr_79   6819 non-null   float64
#  81  Attr_80   6819 non-null   float64
#  82  Attr_81   6819 non-null   float64
#  83  Attr_82   6819 non-null   float64
#  84  Attr_83   6819 non-null   float64
#  85  Attr_84   6819 non-null   float64
#  86  Attr_85   6819 non-null   int64
#  87  Attr_86   6819 non-null   float64
#  88  Attr_87   6819 non-null   float64
#  89  Attr_88   6819 non-null   float64
#  90  Attr_89   6819 non-null   float64
#  91  Attr_90   6819 non-null   float64
#  92  Attr_91   6819 non-null   float64
#  93  Attr_92   6819 non-null   float64
#  94  Attr_93   6819 non-null   float64
#  95  Attr_94   6819 non-null   int64
#  96  Attr_95   6819 non-null   float64
# dtypes: bool(1), float64(93), int64(3)
# memory usage: 5.0 MB

# %% [markdown]
# ### Save changes we made on csv file by wrangle function to new csv file `Taiwan_bankruptcy_modified.csv`

# %%
df.to_csv(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified.csv", index=False)

# %%
df_test=pd.read_csv(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified.csv")
df_test.head()
# Out:
#    id  bankrupt    Attr_1    Attr_2    Attr_3    Attr_4    Attr_5    Attr_6  \
# 0   1      True  0.370594  0.424389  0.405750  0.601457  0.601457  0.998969
# 1   2      True  0.464291  0.538214  0.516730  0.610235  0.610235  0.998946
# 2   3      True  0.426071  0.499019  0.472295  0.601450  0.601364  0.998857
# 3   4      True  0.399844  0.451265  0.457733  0.583541  0.583541  0.998700
# 4   5      True  0.465022  0.538432  0.522298  0.598783  0.598783  0.998973
#
#      Attr_7    Attr_8  ...   Attr_86   Attr_87   Attr_88   Attr_89   Attr_90  \
# 0  0.796887  0.808809  ...  0.716845  0.009219  0.622879  0.601453  0.827890
# 1  0.797380  0.809301  ...  0.795297  0.008323  0.623652  0.610237  0.839969
# 2  0.796403  0.808388  ...  0.774670  0.040003  0.623841  0.601449  0.836774
# 3  0.796967  0.808966  ...  0.739555  0.003252  0.622929  0.583538  0.834697
# 4  0.797366  0.809304  ...  0.795016  0.003878  0.623521  0.598782  0.839973
#
#     Attr_91   Attr_92   Attr_93  Attr_94   Attr_95
# 0  0.290202  0.026601  0.564050        1  0.016469
# 1  0.283846  0.264577  0.570175        1  0.020794
# 2  0.290189  0.026555  0.563706        1  0.016474
# 3  0.281721  0.026697  0.564663        1  0.023982
# 4  0.278514  0.024752  0.575617        1  0.035490
#
# [5 rows x 97 columns]

# %%
df_test["bankrupt"].value_counts()
# Out:
# False    6599
# True      220
# Name: bankrupt, dtype: int64

# %% [markdown]
# ###### After procession  the CSV file,we extracts random rows, sorts them based on the first column, saves them to a new CSV file, and removes the extracted rows from the original file.

# %%
import csv
import random

input_file = r'E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified.csv'
output_file = r'E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified_test.csv'

# Step 1: Read the CSV file
with open(input_file, 'r') as file:
    reader = csv.reader(file)
    rows = list(reader)

    header_row = rows[0]
    data_rows = rows[1:]

    num_data_rows = len(data_rows)
    num_random_rows = 682  # Define the number of random rows you want to extract
    random_indices = random.sample(range(num_data_rows), num_random_rows)

    random_rows = [data_rows[index] for index in random_indices]

    # Step 2: Sort the extracted rows based on the first column
    sorted_rows = sorted(random_rows, key=lambda row: float(row[0]))

    # Step 3: Save the sorted extracted rows in a new CSV file with the header
    with open(output_file, 'w', newline='') as output:
        writer = csv.writer(output)
        writer.writerow(header_row)  # Write the header row
        writer.writerows(sorted_rows)

    # Step 4: Remove the extracted rows from the original CSV file
    remaining_rows = [row for index, row in enumerate(data_rows) if index not in random_indices]

    with open(input_file, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(header_row)  # Write the header row
        writer.writerows(remaining_rows)

# %%
original_csv = pd.read_csv(r'E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified.csv')
print(original_csv.shape)
original_csv.head()
# Out:
# (6137, 97)
#    id  bankrupt    Attr_1    Attr_2    Attr_3    Attr_4    Attr_5    Attr_6  \
# 0   1      True  0.370594  0.424389  0.405750  0.601457  0.601457  0.998969
# 1   2      True  0.464291  0.538214  0.516730  0.610235  0.610235  0.998946
# 2   3      True  0.426071  0.499019  0.472295  0.601450  0.601364  0.998857
# 3   4      True  0.399844  0.451265  0.457733  0.583541  0.583541  0.998700
# 4   5      True  0.465022  0.538432  0.522298  0.598783  0.598783  0.998973
#
#      Attr_7    Attr_8  ...   Attr_86   Attr_87   Attr_88   Attr_89   Attr_90  \
# 0  0.796887  0.808809  ...  0.716845  0.009219  0.622879  0.601453  0.827890
# 1  0.797380  0.809301  ...  0.795297  0.008323  0.623652  0.610237  0.839969
# 2  0.796403  0.808388  ...  0.774670  0.040003  0.623841  0.601449  0.836774
# 3  0.796967  0.808966  ...  0.739555  0.003252  0.622929  0.583538  0.834697
# 4  0.797366  0.809304  ...  0.795016  0.003878  0.623521  0.598782  0.839973
#
#     Attr_91   Attr_92   Attr_93  Attr_94   Attr_95
# 0  0.290202  0.026601  0.564050        1  0.016469
# 1  0.283846  0.264577  0.570175        1  0.020794
# 2  0.290189  0.026555  0.563706        1  0.016474
# 3  0.281721  0.026697  0.564663        1  0.023982
# 4  0.278514  0.024752  0.575617        1  0.035490
#
# [5 rows x 97 columns]

# %%
original_csv['bankrupt'].value_counts()
# Out:
# False    5943
# True      194
# Name: bankrupt, dtype: int64

# %%
# remove bankrupt column from Taiwan_bankruptcy_modified_test.csv
import csv
filename = r'E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified_test.csv'
column_index = 1

with open(filename, 'r', newline='') as file:
    reader = csv.reader(file)
    rows = [row[:column_index] + row[column_index+1:] for row in reader]

with open(filename, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(rows)

# %%
extracted_csv = pd.read_csv(r'E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified_test.csv')
print(extracted_csv.shape)
extracted_csv.head()
# Out:
# (682, 96)
#    id    Attr_1    Attr_2    Attr_3    Attr_4    Attr_5    Attr_6    Attr_7  \
# 0  10  0.495686  0.550916  0.542963  0.599209  0.599209  0.999001  0.797404
# 1  13  0.491152  0.551570  0.543391  0.608131  0.608138  0.999045  0.797429
# 2  40  0.486228  0.548027  0.544140  0.598445  0.598445  0.998953  0.797404
# 3  41  0.507824  0.571631  0.549226  0.625326  0.625326  0.999136  0.797542
# 4  71  0.544825  0.588149  0.589218  0.600636  0.600636  0.999039  0.797469
#
#      Attr_8    Attr_9  ...   Attr_86   Attr_87   Attr_88   Attr_89   Attr_90  \
# 0  0.809320  0.303483  ...  0.804195  0.005798  0.623865  0.599205  0.840688
# 1  0.809344  0.303435  ...  0.803260  0.008232  0.623578  0.608125  0.840702
# 2  0.809343  0.303584  ...  0.801372  0.003425  0.623089  0.598440  0.840386
# 3  0.809413  0.303442  ...  0.815731  0.007173  0.623729  0.625327  0.841574
# 4  0.809371  0.303517  ...  0.827985  0.004125  0.623411  0.600633  0.842319
#
#     Attr_91   Attr_92   Attr_93  Attr_94   Attr_95
# 0  0.279388  0.027243  0.566668        1  0.030801
# 1  0.281113  0.027480  0.567146        1  0.025282
# 2  0.277247  0.028873  0.568501        1  0.047960
# 3  0.279236  0.026908  0.565659        1  0.031485
# 4  0.278315  0.026871  0.565512        1  0.036871
#
# [5 rows x 96 columns]

# %% [markdown]
# ### Create JSON file

# %%
Taiwan_bankruptcy_modified = {
     "schema": {
               "fields":[{'name': 'company_id', 'type': 'integer'},
                         {'name': 'bankrupt', 'type': 'boolean'},
                         {'name': 'Attr_1', 'type': 'number'},
                         {'name': 'Attr_2', 'type': 'number'},
                         {'name': 'Attr_3', 'type': 'number'},
                         {'name': 'Attr_4', 'type': 'number'},
                         {'name': 'Attr_5', 'type': 'number'},
                         {'name': 'Attr_6', 'type': 'number'},
                         {'name': 'Attr_7', 'type': 'number'},
                         {'name': 'Attr_8', 'type': 'number'},
                         {'name': 'Attr_9', 'type': 'number'},
                         {'name': 'Attr_10', 'type': 'number'},
                         {'name': 'Attr_11', 'type': 'number'},
                         {'name': 'Attr_12', 'type': 'number'},
                         {'name': 'Attr_13', 'type': 'number'},
                         {'name': 'Attr_14', 'type': 'number'},
                         {'name': 'Attr_15', 'type': 'number'},
                         {'name': 'Attr_16', 'type': 'number'},
                         {'name': 'Attr_17', 'type': 'number'},
                         {'name': 'Attr_18', 'type': 'number'},
                         {'name': 'Attr_19', 'type': 'number'},
                         {'name': 'Attr_20', 'type': 'number'},
                         {'name': 'Attr_21', 'type': 'number'},
                         {'name': 'Attr_22', 'type': 'number'},
                         {'name': 'Attr_23', 'type': 'number'},
                         {'name': 'Attr_24', 'type': 'number'},
                         {'name': 'Attr_25', 'type': 'number'},
                         {'name': 'Attr_26', 'type': 'number'},
                         {'name': 'Attr_27', 'type': 'number'},
                         {'name': 'Attr_28', 'type': 'number'},
                         {'name': 'Attr_29', 'type': 'number'},
                         {'name': 'Attr_30', 'type': 'number'},
                         {'name': 'Attr_31', 'type': 'number'},
                         {'name': 'Attr_32', 'type': 'number'},
                         {'name': 'Attr_33', 'type': 'number'},
                         {'name': 'Attr_34', 'type': 'number'},
                         {'name': 'Attr_35', 'type': 'number'},
                         {'name': 'Attr_36', 'type': 'number'},
                         {'name': 'Attr_37', 'type': 'number'},
                         {'name': 'Attr_38', 'type': 'number'},
                         {'name': 'Attr_39', 'type': 'number'},
                         {'name': 'Attr_40', 'type': 'number'},
                         {'name': 'Attr_41', 'type': 'number'},
                         {'name': 'Attr_42', 'type': 'number'},
                         {'name': 'Attr_43', 'type': 'number'},
                         {'name': 'Attr_44', 'type': 'number'},
                         {'name': 'Attr_45', 'type': 'number'},
                         {'name': 'Attr_46', 'type': 'number'},
                         {'name': 'Attr_47', 'type': 'number'},
                         {'name': 'Attr_48', 'type': 'number'},
                         {'name': 'Attr_49', 'type': 'number'},
                         {'name': 'Attr_50', 'type': 'number'},
                         {'name': 'Attr_51', 'type': 'number'},
                         {'name': 'Attr_52', 'type': 'number'},
                         {'name': 'Attr_53', 'type': 'number'},
                         {'name': 'Attr_54', 'type': 'number'},
                         {'name': 'Attr_55', 'type': 'number'},
                         {'name': 'Attr_56', 'type': 'number'},
                         {'name': 'Attr_57', 'type': 'number'},
                         {'name': 'Attr_58', 'type': 'number'},
                         {'name': 'Attr_59', 'type': 'number'},
                         {'name': 'Attr_60', 'type': 'number'},
                         {'name': 'Attr_61', 'type': 'number'},
                         {'name': 'Attr_62', 'type': 'number'},
                         {'name': 'Attr_63', 'type': 'number'},
                         {'name': 'Attr_64', 'type': 'number'},
                         {'name': 'Attr_65', 'type': 'number'},
                         {'name': 'Attr_66', 'type': 'number'},
                         {'name': 'Attr_67', 'type': 'number'},
                         {'name': 'Attr_68', 'type': 'number'},
                         {'name': 'Attr_69', 'type': 'number'},
                         {'name': 'Attr_70', 'type': 'number'},
                         {'name': 'Attr_71', 'type': 'number'},
                         {'name': 'Attr_72', 'type': 'number'},
                         {'name': 'Attr_73', 'type': 'number'},
                         {'name': 'Attr_74', 'type': 'number'},
                         {'name': 'Attr_75', 'type': 'number'},
                         {'name': 'Attr_76', 'type': 'number'},
                         {'name': 'Attr_77', 'type': 'number'},
                         {'name': 'Attr_78', 'type': 'number'},
                         {'name': 'Attr_79', 'type': 'number'},
                         {'name': 'Attr_80', 'type': 'number'},
                         {'name': 'Attr_81', 'type': 'number'},
                         {'name': 'Attr_82', 'type': 'number'},
                         {'name': 'Attr_83', 'type': 'number'},
                         {'name': 'Attr_84', 'type': 'number'},
                         {'name': 'Attr_85', 'type': 'integer'},
                         {'name': 'Attr_86', 'type': 'number'},
                         {'name': 'Attr_87', 'type': 'number'},
                         {'name': 'Attr_88', 'type': 'number'},
                         {'name': 'Attr_89', 'type': 'number'},
                         {'name': 'Attr_90', 'type': 'number'},
                         {'name': 'Attr_91', 'type': 'number'},
                         {'name': 'Attr_92', 'type': 'number'},
                         {'name': 'Attr_93', 'type': 'number'},
                         {'name': 'Attr_94', 'type': 'integer'},
                         {'name': 'Attr_95', 'type': 'number'}],
               "primary_key":["company_id"],
                "pandas_version":"0.20.0"
              },
    "observations": [],
    "metadata": {'title': 'Financial ratios and corporate governance indicators in bankruptcy prediction: A comprehensive study',
                 'authors': 'Deron Liang, Chia-Chi Lu, Chih-Fong Tsai, Guan-An Shih',
                 'journal': 'European Journal of Operational Research',
                 'publicationYear': 2016,
                 'articleLink': 'https://doi.org/10.1016/j.ejor.2016.01.012',
                 'datasetLink': 'https://archive.ics.uci.edu/ml/datasets/Taiwanese+Bankruptcy+Prediction'}
    }
with open(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified.json","w") as file:
    json.dump(Taiwan_bankruptcy_modified,file,ensure_ascii=False,indent=4)

# %% [markdown]
# By the end of the loop, the `dict_data` list will contain dictionaries, with each dictionary representing a row of data from the CSV file.

# %% [markdown]
# # Note

# %% [markdown]
# The csv.`DictReader` function in Python's csv module reads values from a CSV file as strings by default. This behavior is intentional because CSV files are text-based and do not have explicit data types defined for the values. Therefore, all values in the CSV file are initially treated as strings.

# %% [markdown]
# So if we append the data from a CSV file as dictionaries, the data types of values will be treated as strings. To avoid this problem, there are two solutions: one is to fix the data types of values before appending them to the JSON file, and the other is to fix the data types of values after appending them to the JSON file.

# %% [markdown]
# ##### In this Notebook, we will fix the data types of values after appending them to the JSON file.

# %%
dict_data_1=[]
import csv
        
with open(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified.csv", newline='') as f:
    reader = csv.DictReader(f)
    
    for row in reader:
                
        dict_data_1.append(row)

# %%
json_file = Path(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified.json")
json_data = json.loads(json_file.read_text())

data = [index for index in dict_data_1]
json_data["observations"] = data

json_file.write_text(json.dumps(json_data))
# Out:
# 18720448

# %%
def wrangle_1(filename):
    
    # Open compressed file, load into dictionary
    with open(filename,"r") as f:
        data = json.load(f)
    # Load dictionary into DataFrame, set index
    df=pd.DataFrame.from_dict(data["observations"])
    
    return df

# %%
df1 = wrangle_1(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified.json")
print(df1.shape)
df1.head()
# Out:
# (6137, 97)
#    id  bankrupt    Attr_1    Attr_2    Attr_3    Attr_4    Attr_5    Attr_6  \
# 0   1      True  0.370594  0.424389  0.405750  0.601457  0.601457  0.998969
# 1   2      True  0.464291  0.538214  0.516730  0.610235  0.610235  0.998946
# 2   3      True  0.426071  0.499019  0.472295  0.601450  0.601364  0.998857
# 3   4      True  0.399844  0.451265  0.457733  0.583541  0.583541  0.998700
# 4   5      True  0.465022  0.538432  0.522298  0.598783  0.598783  0.998973
#
#      Attr_7    Attr_8  ...   Attr_86   Attr_87   Attr_88   Attr_89   Attr_90  \
# 0  0.796887  0.808809  ...  0.716845  0.009219  0.622879  0.601453  0.827890
# 1  0.797380  0.809301  ...  0.795297  0.008323  0.623652  0.610237  0.839969
# 2  0.796403  0.808388  ...  0.774670  0.040003  0.623841  0.601449  0.836774
# 3  0.796967  0.808966  ...  0.739555  0.003252  0.622929  0.583538  0.834697
# 4  0.797366  0.809304  ...  0.795016  0.003878  0.623521  0.598782  0.839973
#
#     Attr_91   Attr_92   Attr_93  Attr_94   Attr_95
# 0  0.290202  0.026601  0.564050        1  0.016469
# 1  0.283846  0.264577  0.570175        1  0.020794
# 2  0.290189  0.026555  0.563706        1  0.016474
# 3  0.281721  0.026697  0.564663        1  0.023982
# 4  0.278514  0.024752  0.575617        1  0.035490
#
# [5 rows x 97 columns]

# %%
df1["bankrupt"].value_counts()
# Out:
# False    5943
# True      194
# Name: bankrupt, dtype: int64

# %%
# Step 1: Read the JSON file
with open(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified.json", 'r') as file:
    data = json.load(file)

# Step 2: Traverse and locate the value to change
list_item = data["observations"][0:]  
for dictionary in list_item:

    for key, value in dictionary.items():
        
        if value=='':
            dictionary[key] = None
            
        elif key=='id':
            dictionary[key] = int(value)
        
        
        elif key=='bankrupt':
            dictionary[key] = True if value == "True" else False
        
        
        
        elif key.startswith('Attr') and key not in ['Attr_85', 'Attr_94']:
            dictionary[key] = float(value)
            
        elif key  in ['Attr_85','Attr_94']:
            dictionary[key] = int(value)     
            
        else :
            pass


# Step 3: Write the modified object back to the JSON file
with open(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified.json", 'w') as file:
    json.dump(data, file, indent=4)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6137 entries, 0 to 6136
# Data columns (total 97 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        6137 non-null   object
#  1   bankrupt  6137 non-null   object
#  2   Attr_1    6137 non-null   object
#  3   Attr_2    6137 non-null   object
#  4   Attr_3    6137 non-null   object
#  5   Attr_4    6137 non-null   object
#  6   Attr_5    6137 non-null   object
#  7   Attr_6    6137 non-null   object
#  8   Attr_7    6137 non-null   object
#  9   Attr_8    6137 non-null   object
#  10  Attr_9    6137 non-null   object
#  11  Attr_10   6137 non-null   object
#  12  Attr_11   6137 non-null   object
#  13  Attr_12   6137 non-null   object
#  14  Attr_13   6137 non-null   object
#  15  Attr_14   6137 non-null   object
#  16  Attr_15   6137 non-null   object
#  17  Attr_16   6137 non-null   object
#  18  Attr_17   6137 non-null   object
#  19  Attr_18   6137 non-null   object
#  20  Attr_19   6137 non-null   object
#  21  Attr_20   6137 non-null   object
#  22  Attr_21   6137 non-null   object
#  23  Attr_22   6137 non-null   object
#  24  Attr_23   6137 non-null   object
#  25  Attr_24   6137 non-null   object
#  26  Attr_25   6137 non-null   object
#  27  Attr_26   6137 non-null   object
#  28  Attr_27   6137 non-null   object
#  29  Attr_28   6137 non-null   object
#  30  Attr_29   6137 non-null   object
#  31  Attr_30   6137 non-null   object
#  32  Attr_31   6137 non-null   object
#  33  Attr_32   6137 non-null   object
#  34  Attr_33   6137 non-null   object
#  35  Attr_34   6137 non-null   object
#  36  Attr_35   6137 non-null   object
#  37  Attr_36   6137 non-null   object
#  38  Attr_37   6137 non-null   object
#  39  Attr_38   6137 non-null   object
#  40  Attr_39   6137 non-null   object
#  41  Attr_40   6137 non-null   object
#  42  Attr_41   6137 non-null   object
#  43  Attr_42   6137 non-null   object
#  44  Attr_43   6137 non-null   object
#  45  Attr_44   6137 non-null   object
#  46  Attr_45   6137 non-null   object
#  47  Attr_46   6137 non-null   object
#  48  Attr_47   6137 non-null   object
#  49  Attr_48   6137 non-null   object
#  50  Attr_49   6137 non-null   object
#  51  Attr_50   6137 non-null   object
#  52  Attr_51   6137 non-null   object
#  53  Attr_52   6137 non-null   object
#  54  Attr_53   6137 non-null   object
#  55  Attr_54   6137 non-null   object
#  56  Attr_55   6137 non-null   object
#  57  Attr_56   6137 non-null   object
#  58  Attr_57   6137 non-null   object
#  59  Attr_58   6137 non-null   object
#  60  Attr_59   6137 non-null   object
#  61  Attr_60   6137 non-null   object
#  62  Attr_61   6137 non-null   object
#  63  Attr_62   6137 non-null   object
#  64  Attr_63   6137 non-null   object
#  65  Attr_64   6137 non-null   object
#  66  Attr_65   6137 non-null   object
#  67  Attr_66   6137 non-null   object
#  68  Attr_67   6137 non-null   object
#  69  Attr_68   6137 non-null   object
#  70  Attr_69   6137 non-null   object
#  71  Attr_70   6137 non-null   object
#  72  Attr_71   6137 non-null   object
#  73  Attr_72   6137 non-null   object
#  74  Attr_73   6137 non-null   object
#  75  Attr_74   6137 non-null   object
#  76  Attr_75   6137 non-null   object
#  77  Attr_76   6137 non-null   object
#  78  Attr_77   6137 non-null   object
#  79  Attr_78   6137 non-null   object
#  80  Attr_79   6137 non-null   object
#  81  Attr_80   6137 non-null   object
#  82  Attr_81   6137 non-null   object
#  83  Attr_82   6137 non-null   object
#  84  Attr_83   6137 non-null   object
#  85  Attr_84   6137 non-null   object
#  86  Attr_85   6137 non-null   object
#  87  Attr_86   6137 non-null   object
#  88  Attr_87   6137 non-null   object
#  89  Attr_88   6137 non-null   object
#  90  Attr_89   6137 non-null   object
#  91  Attr_90   6137 non-null   object
#  92  Attr_91   6137 non-null   object
#  93  Attr_92   6137 non-null   object
#  94  Attr_93   6137 non-null   object
#  95  Attr_94   6137 non-null   object
#  96  Attr_95   6137 non-null   object
# dtypes: object(97)
# memory usage: 4.5+ MB

# %%
# gzip compress file
with open(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified.json",'rb') as f_input:
    with gzip.open(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified.json.gz",'wb') as f_output:
        shutil.copyfileobj(f_input,f_output)

# %%
Taiwan_bankruptcy_modified_test = {
     "schema": {
               "fields":[{'name': 'company_id', 'type': 'integer'},
                         {'name': 'Attr_1', 'type': 'number'},
                         {'name': 'Attr_2', 'type': 'number'},
                         {'name': 'Attr_3', 'type': 'number'},
                         {'name': 'Attr_4', 'type': 'number'},
                         {'name': 'Attr_5', 'type': 'number'},
                         {'name': 'Attr_6', 'type': 'number'},
                         {'name': 'Attr_7', 'type': 'number'},
                         {'name': 'Attr_8', 'type': 'number'},
                         {'name': 'Attr_9', 'type': 'number'},
                         {'name': 'Attr_10', 'type': 'number'},
                         {'name': 'Attr_11', 'type': 'number'},
                         {'name': 'Attr_12', 'type': 'number'},
                         {'name': 'Attr_13', 'type': 'number'},
                         {'name': 'Attr_14', 'type': 'number'},
                         {'name': 'Attr_15', 'type': 'number'},
                         {'name': 'Attr_16', 'type': 'number'},
                         {'name': 'Attr_17', 'type': 'number'},
                         {'name': 'Attr_18', 'type': 'number'},
                         {'name': 'Attr_19', 'type': 'number'},
                         {'name': 'Attr_20', 'type': 'number'},
                         {'name': 'Attr_21', 'type': 'number'},
                         {'name': 'Attr_22', 'type': 'number'},
                         {'name': 'Attr_23', 'type': 'number'},
                         {'name': 'Attr_24', 'type': 'number'},
                         {'name': 'Attr_25', 'type': 'number'},
                         {'name': 'Attr_26', 'type': 'number'},
                         {'name': 'Attr_27', 'type': 'number'},
                         {'name': 'Attr_28', 'type': 'number'},
                         {'name': 'Attr_29', 'type': 'number'},
                         {'name': 'Attr_30', 'type': 'number'},
                         {'name': 'Attr_31', 'type': 'number'},
                         {'name': 'Attr_32', 'type': 'number'},
                         {'name': 'Attr_33', 'type': 'number'},
                         {'name': 'Attr_34', 'type': 'number'},
                         {'name': 'Attr_35', 'type': 'number'},
                         {'name': 'Attr_36', 'type': 'number'},
                         {'name': 'Attr_37', 'type': 'number'},
                         {'name': 'Attr_38', 'type': 'number'},
                         {'name': 'Attr_39', 'type': 'number'},
                         {'name': 'Attr_40', 'type': 'number'},
                         {'name': 'Attr_41', 'type': 'number'},
                         {'name': 'Attr_42', 'type': 'number'},
                         {'name': 'Attr_43', 'type': 'number'},
                         {'name': 'Attr_44', 'type': 'number'},
                         {'name': 'Attr_45', 'type': 'number'},
                         {'name': 'Attr_46', 'type': 'number'},
                         {'name': 'Attr_47', 'type': 'number'},
                         {'name': 'Attr_48', 'type': 'number'},
                         {'name': 'Attr_49', 'type': 'number'},
                         {'name': 'Attr_50', 'type': 'number'},
                         {'name': 'Attr_51', 'type': 'number'},
                         {'name': 'Attr_52', 'type': 'number'},
                         {'name': 'Attr_53', 'type': 'number'},
                         {'name': 'Attr_54', 'type': 'number'},
                         {'name': 'Attr_55', 'type': 'number'},
                         {'name': 'Attr_56', 'type': 'number'},
                         {'name': 'Attr_57', 'type': 'number'},
                         {'name': 'Attr_58', 'type': 'number'},
                         {'name': 'Attr_59', 'type': 'number'},
                         {'name': 'Attr_60', 'type': 'number'},
                         {'name': 'Attr_61', 'type': 'number'},
                         {'name': 'Attr_62', 'type': 'number'},
                         {'name': 'Attr_63', 'type': 'number'},
                         {'name': 'Attr_64', 'type': 'number'},
                         {'name': 'Attr_65', 'type': 'number'},
                         {'name': 'Attr_66', 'type': 'number'},
                         {'name': 'Attr_67', 'type': 'number'},
                         {'name': 'Attr_68', 'type': 'number'},
                         {'name': 'Attr_69', 'type': 'number'},
                         {'name': 'Attr_70', 'type': 'number'},
                         {'name': 'Attr_71', 'type': 'number'},
                         {'name': 'Attr_72', 'type': 'number'},
                         {'name': 'Attr_73', 'type': 'number'},
                         {'name': 'Attr_74', 'type': 'number'},
                         {'name': 'Attr_75', 'type': 'number'},
                         {'name': 'Attr_76', 'type': 'number'},
                         {'name': 'Attr_77', 'type': 'number'},
                         {'name': 'Attr_78', 'type': 'number'},
                         {'name': 'Attr_79', 'type': 'number'},
                         {'name': 'Attr_80', 'type': 'number'},
                         {'name': 'Attr_81', 'type': 'number'},
                         {'name': 'Attr_82', 'type': 'number'},
                         {'name': 'Attr_83', 'type': 'number'},
                         {'name': 'Attr_84', 'type': 'number'},
                         {'name': 'Attr_85', 'type': 'integer'},
                         {'name': 'Attr_86', 'type': 'number'},
                         {'name': 'Attr_87', 'type': 'number'},
                         {'name': 'Attr_88', 'type': 'number'},
                         {'name': 'Attr_89', 'type': 'number'},
                         {'name': 'Attr_90', 'type': 'number'},
                         {'name': 'Attr_91', 'type': 'number'},
                         {'name': 'Attr_92', 'type': 'number'},
                         {'name': 'Attr_93', 'type': 'number'},
                         {'name': 'Attr_94', 'type': 'integer'},
                         {'name': 'Attr_95', 'type': 'number'}],
               "primary_key":["company_id"],
                "pandas_version":"0.20.0"
              },
    "observations": [],
    "metadata": {'title': 'Financial ratios and corporate governance indicators in bankruptcy prediction: A comprehensive study',
                 'authors': 'Deron Liang, Chia-Chi Lu, Chih-Fong Tsai, Guan-An Shih',
                 'journal': 'European Journal of Operational Research',
                 'publicationYear': 2016,
                 'articleLink': 'https://doi.org/10.1016/j.ejor.2016.01.012',
                 'datasetLink': 'https://archive.ics.uci.edu/ml/datasets/Taiwanese+Bankruptcy+Prediction'}
    }
with open(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified_test.json","w") as file:
    json.dump(Taiwan_bankruptcy_modified_test,file,ensure_ascii=False,indent=4)

# %%
dict_data_2=[]
import csv
        
with open(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified_test.csv", newline='') as f:
    reader = csv.DictReader(f)
    
    for row in reader:
               
        dict_data_2.append(row)

# %%
json_file = Path(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified_test.json")
json_data = json.loads(json_file.read_text())

data = [index for index in dict_data_2]
json_data["observations"] = data

json_file.write_text(json.dumps(json_data))
# Out:
# 2069750

# %%
def wrangle_2(filename):
    
    # Open compressed file, load into dictionary
    with open(filename,"r") as f:
        data = json.load(f)
    # Load dictionary into DataFrame, set index
    df=pd.DataFrame.from_dict(data["observations"])
    
    return df

# %%
df2 = wrangle_2(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified_test.json")
print(df2.shape)
df2.head()
# Out:
# (682, 96)
#    id             Attr_1             Attr_2             Attr_3  \
# 0  10  0.495685662750451  0.550915830789359  0.542962685368596
# 1  13  0.491151952420416  0.551569995638901  0.543390973820868
# 2  40  0.486228245502852  0.548026602703881  0.544140478612345
# 3  41  0.507824306537318  0.571631051024858  0.549226403983083
# 4  71  0.544825232779213  0.588148713475796  0.589217838214037
#
#               Attr_4             Attr_5             Attr_6             Attr_7  \
# 0  0.599208694273483  0.599208694273483  0.999000632043326  0.797403570816415
# 1  0.608130702373917  0.608137909165598  0.999044886630839  0.797428887121513
# 2  0.598444774355353  0.598444774355353  0.998953142133487  0.797404400859205
# 3  0.625326107323542  0.625326107323542  0.999135706750384    0.7975416346005
# 4  0.600635639026218  0.600635639026218  0.999038647080641  0.797468867515902
#
#               Attr_8             Attr_9  ...            Attr_86  \
# 0  0.809320385467476  0.303482953821731  ...  0.804194656500343
# 1  0.809344341779496  0.303434855738379  ...  0.803260160615522
# 2  0.809343300200712   0.30358374226775  ...  0.801371569744629
# 3    0.8094133463739  0.303441623307896  ...  0.815731085142529
# 4  0.809370902038474  0.303517275067138  ...  0.827984672530329
#
#               Attr_87            Attr_88            Attr_89  \
# 0   0.005797642207721  0.623865043621207  0.599205074060972
# 1   0.008232490111815   0.62357757367742  0.608125444361497
# 2  0.0034249823452305  0.623089158340436  0.598440276500219
# 3   0.007173154537515  0.623729409498007  0.625326634759901
# 4  0.0041247924464135  0.623411192820107  0.600633492612391
#
#              Attr_90            Attr_91             Attr_92  \
# 0  0.840688177069564  0.279387518743906  0.0272430149466587
# 1  0.840702415877267  0.281113383864046  0.0274797246787734
# 2  0.840385757478808  0.277247090635208  0.0288727658138465
# 3  0.841573616502083  0.279235950325587   0.026907690710701
# 4  0.842318562340046  0.278315149342696   0.026870881562317
#
#              Attr_93 Attr_94             Attr_95
# 0  0.566667622359207       1  0.0308008650901007
# 1  0.567146326659175       1  0.0252817202305257
# 2  0.568500549655657       1  0.0479599415621359
# 3  0.565658865268012       1  0.0314853592017782
# 4  0.565511873396239       1  0.0368709257372074
#
# [5 rows x 96 columns]

# %%
# Step 1: Read the JSON file
with open(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified_test.json", 'r') as file:
    data = json.load(file)

# Step 2: Traverse and locate the value to change
list_item = data["observations"][0:]  
for dictionary in list_item:

    for key, value in dictionary.items():
        
        if value=='':
            dictionary[key] = None
            
        elif key=='id':
            dictionary[key] = int(value)
        
        elif key.startswith('Attr') and key not in ['Attr_85', 'Attr_94']:
            dictionary[key] = float(value)
            
        elif key  in ['Attr_85','Attr_94']:
            dictionary[key] = int(value)     
            
        else :
            pass


# Step 3: Write the modified object back to the JSON file
with open(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified_test.json", 'w') as file:
    json.dump(data, file, indent=4)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 96 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       682 non-null    object
#  1   Attr_1   682 non-null    object
#  2   Attr_2   682 non-null    object
#  3   Attr_3   682 non-null    object
#  4   Attr_4   682 non-null    object
#  5   Attr_5   682 non-null    object
#  6   Attr_6   682 non-null    object
#  7   Attr_7   682 non-null    object
#  8   Attr_8   682 non-null    object
#  9   Attr_9   682 non-null    object
#  10  Attr_10  682 non-null    object
#  11  Attr_11  682 non-null    object
#  12  Attr_12  682 non-null    object
#  13  Attr_13  682 non-null    object
#  14  Attr_14  682 non-null    object
#  15  Attr_15  682 non-null    object
#  16  Attr_16  682 non-null    object
#  17  Attr_17  682 non-null    object
#  18  Attr_18  682 non-null    object
#  19  Attr_19  682 non-null    object
#  20  Attr_20  682 non-null    object
#  21  Attr_21  682 non-null    object
#  22  Attr_22  682 non-null    object
#  23  Attr_23  682 non-null    object
#  24  Attr_24  682 non-null    object
#  25  Attr_25  682 non-null    object
#  26  Attr_26  682 non-null    object
#  27  Attr_27  682 non-null    object
#  28  Attr_28  682 non-null    object
#  29  Attr_29  682 non-null    object
#  30  Attr_30  682 non-null    object
#  31  Attr_31  682 non-null    object
#  32  Attr_32  682 non-null    object
#  33  Attr_33  682 non-null    object
#  34  Attr_34  682 non-null    object
#  35  Attr_35  682 non-null    object
#  36  Attr_36  682 non-null    object
#  37  Attr_37  682 non-null    object
#  38  Attr_38  682 non-null    object
#  39  Attr_39  682 non-null    object
#  40  Attr_40  682 non-null    object
#  41  Attr_41  682 non-null    object
#  42  Attr_42  682 non-null    object
#  43  Attr_43  682 non-null    object
#  44  Attr_44  682 non-null    object
#  45  Attr_45  682 non-null    object
#  46  Attr_46  682 non-null    object
#  47  Attr_47  682 non-null    object
#  48  Attr_48  682 non-null    object
#  49  Attr_49  682 non-null    object
#  50  Attr_50  682 non-null    object
#  51  Attr_51  682 non-null    object
#  52  Attr_52  682 non-null    object
#  53  Attr_53  682 non-null    object
#  54  Attr_54  682 non-null    object
#  55  Attr_55  682 non-null    object
#  56  Attr_56  682 non-null    object
#  57  Attr_57  682 non-null    object
#  58  Attr_58  682 non-null    object
#  59  Attr_59  682 non-null    object
#  60  Attr_60  682 non-null    object
#  61  Attr_61  682 non-null    object
#  62  Attr_62  682 non-null    object
#  63  Attr_63  682 non-null    object
#  64  Attr_64  682 non-null    object
#  65  Attr_65  682 non-null    object
#  66  Attr_66  682 non-null    object
#  67  Attr_67  682 non-null    object
#  68  Attr_68  682 non-null    object
#  69  Attr_69  682 non-null    object
#  70  Attr_70  682 non-null    object
#  71  Attr_71  682 non-null    object
#  72  Attr_72  682 non-null    object
#  73  Attr_73  682 non-null    object
#  74  Attr_74  682 non-null    object
#  75  Attr_75  682 non-null    object
#  76  Attr_76  682 non-null    object
#  77  Attr_77  682 non-null    object
#  78  Attr_78  682 non-null    object
#  79  Attr_79  682 non-null    object
#  80  Attr_80  682 non-null    object
#  81  Attr_81  682 non-null    object
#  82  Attr_82  682 non-null    object
#  83  Attr_83  682 non-null    object
#  84  Attr_84  682 non-null    object
#  85  Attr_85  682 non-null    object
#  86  Attr_86  682 non-null    object
#  87  Attr_87  682 non-null    object
#  88  Attr_88  682 non-null    object
#  89  Attr_89  682 non-null    object
#  90  Attr_90  682 non-null    object
#  91  Attr_91  682 non-null    object
#  92  Attr_92  682 non-null    object
#  93  Attr_93  682 non-null    object
#  94  Attr_94  682 non-null    object
#  95  Attr_95  682 non-null    object
# dtypes: object(96)
# memory usage: 511.6+ KB

# %%
# gzip compress file
with open(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified_test.json",'rb') as f_input:
    with gzip.open(r"E:\WorldQuant\project_5\data\Taiwan_bankruptcy_modified_test.json.gz",'wb') as f_output:
        shutil.copyfileobj(f_input,f_output)
